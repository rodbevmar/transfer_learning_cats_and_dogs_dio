# %%
# Baseado em https://github.com/SilvanFelipe/transfer_learning_cats_and_dogs/blob/main/tranfer_learning_cats_and_dogs.ipynb
# Importação das bibliotecas necessárias
import os
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %%
# Função para download do dataset
def download_dataset(url, output_path):
    if not os.path.exists(output_path):
        os.system(f'wget --no-check-certificate {url} -O {output_path}')

# Download e extração do dataset
data_url = "https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip"
data_path = "/content/catsdogs.zip"
base_dir = "/content/cats_and_dogs_filtered/"
download_dataset(data_url, data_path)

with zipfile.ZipFile(data_path, 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
# Diretórios de treino, validação e teste
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Carregamento dos datasets
def load_datasets(train_dir, validation_dir, img_size=(150, 150), batch_size=32):
    training_set = image_dataset_from_directory(
        train_dir,
        shuffle=True,
        batch_size=batch_size,
        image_size=img_size
    )
    val_dataset = image_dataset_from_directory(
        validation_dir,
        shuffle=True,
        batch_size=batch_size,
        image_size=img_size
    )
    return training_set, val_dataset

training_set, val_dataset = load_datasets(train_dir, validation_dir)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
# Data augmentation
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip("horizontal"),
    keras.layers.RandomRotation(0.1),
])

# %%
# Carregamento do modelo VGG16 pré-treinado
vgg = keras.applications.VGG16(
    weights='imagenet',
    input_shape=(150, 150, 3),
    include_top=False
)
vgg.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Criação do modelo
def create_model(base_model, data_augmentation):
    inputs = keras.Input(shape=(150, 150, 3))
    x = data_augmentation(inputs)
    x = tf.keras.applications.vgg16.preprocess_input(x)
    x = base_model(x, training=False)
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dropout(0.2)(x)
    outputs = keras.layers.Dense(1, activation='sigmoid')(x)
    model = keras.Model(inputs, outputs)
    return model

model = create_model(vgg, data_augmentation)

# %%
# Compilação do modelo
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()]
)

# %%
# Treinamento inicial
initial_epochs = 20
callbacks = [
    EarlyStopping(patience=5),
    TensorBoard(log_dir="logs")
]

history = model.fit(
    training_set,
    validation_data=val_dataset,
    epochs=initial_epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - binary_accuracy: 0.6165 - loss: 2.8837 - val_binary_accuracy: 0.8900 - val_loss: 0.5538
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - binary_accuracy: 0.8482 - loss: 0.8435 - val_binary_accuracy: 0.9200 - val_loss: 0.3583
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - binary_accuracy: 0.8786 - loss: 0.6125 - val_binary_accuracy: 0.9410 - val_loss: 0.2755
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - binary_accuracy: 0.9096 - loss: 0.4237 - val_binary_accuracy: 0.9470 - val_loss: 0.2441
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - binary_accuracy: 0.9208 - loss: 0.5024 - val_binary_accuracy: 0.9520 - val_loss: 0.2311
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - binary_accuracy: 0.9220 - loss: 0.2896 - val_binary_accuracy: 0.9430 - val_loss: 0.2337
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - binary_accuracy: 0.9341 - loss: 0.2795 - val_binary_accuracy: 0.9530 - val_loss: 0.2056
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - binary_accuracy: 0.9439 - loss: 0.2060 - val_binary_accuracy: 0.9580 - val_loss: 0.1965
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - binary_accuracy: 0.9286 - loss: 0.2745 - val_binary_accuracy: 0.9600 - val_loss: 0.1867
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - binary_accuracy: 0.9346 - loss: 0.2709 - val_binary_accuracy: 0.9620 - val_loss: 0.1872
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - binary_accuracy: 0.9475 - loss: 0.2197 - val_binary_accuracy: 0.9620 - val_loss: 0.1870
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - binary_accuracy: 0.9555 - loss: 0.1575 - val_binary_accuracy: 0.9600 - val_loss: 0.1887
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - binary_accuracy: 0.9592 - loss: 0.1656 - val_binary_accuracy: 0.9610 - val_loss: 0.1828
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 109ms/step - binary_accuracy: 0.9489 - loss: 0.1699 - val_binary_accuracy: 0.9610 - val_loss: 0.1765
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - binary_accuracy: 0.9466 - loss: 0.2128 - val_binary_accuracy: 0.9600 - val_loss: 0.1763
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - binary_accuracy: 0.9562 - loss: 0.1388 - val_binary_accuracy: 0.9660 - val_loss: 0.1596
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - binary_accuracy: 0.9497 - loss: 0.1956 - val_binary_accuracy: 0.9690 - val_loss: 0.1540
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - binary_accuracy: 0.9611 - loss: 0.1397 - val_binary_accuracy: 0.9690 - val_loss: 0.1501
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - binary_accuracy: 0.9447 - loss: 0.1904 - val_binary_accuracy: 0.9610 - val_loss: 0.1586
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - binary_accuracy: 0.9518 - loss: 0.1609 - val_binary_accuracy: 0.9690 - val_loss: 0.1535

# %%
# Visualização dos resultados
def plot_training_history(history):
    acc = history.history['binary_accuracy']
    val_acc = history.history['val_binary_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='upper right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 1.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

plot_training_history(history)

# %%
# Fine-tuning
def fine_tune_model(base_model, model, training_set, val_dataset, initial_epochs, fine_tune_epochs=10):
    base_model.trainable = True
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-5),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[keras.metrics.BinaryAccuracy()]
    )
    history = model.fit(
        training_set,
        validation_data=val_dataset,
        epochs=initial_epochs + fine_tune_epochs,
        initial_epoch=initial_epochs,
        callbacks=callbacks
    )
    return history

fine_tune_history = fine_tune_model(vgg, model, training_set, val_dataset, initial_epochs)
plot_training_history(fine_tune_history)
# Out:
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 309ms/step - binary_accuracy: 0.9486 - loss: 0.1664 - val_binary_accuracy: 0.9670 - val_loss: 0.1018
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - binary_accuracy: 0.9667 - loss: 0.0841 - val_binary_accuracy: 0.9690 - val_loss: 0.1001
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - binary_accuracy: 0.9660 - loss: 0.0757 - val_binary_accuracy: 0.9690 - val_loss: 0.1051
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - binary_accuracy: 0.9776 - loss: 0.0665 - val_binary_accuracy: 0.9740 - val_loss: 0.0868
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - binary_accuracy: 0.9913 - loss: 0.0291 - val_binary_accuracy: 0.9660 - val_loss: 0.0985
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - binary_accuracy: 0.9899 - loss: 0.0211 - val_binary_accuracy: 0.9690 - val_loss: 0.1056
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 262ms/step - binary_accuracy: 0.9924 - loss: 0.0260 - val_binary_accuracy: 0.9660 - val_loss: 0.0965
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 270ms/step - binary_accuracy: 0.9886 - loss: 0.0339 - val_binary_accuracy: 0.9710 - val_loss: 0.0909
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 269ms/step - binary_accuracy: 0.9860 - loss: 0.0273 - val_binary_accuracy: 0.9760 - val_loss: 0.0864
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - binary_accuracy: 0.9898 - loss: 0.0257 - val_binary_accuracy: 0.9720 - val_loss: 0.0828
